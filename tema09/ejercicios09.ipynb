# %% [markdown]
# # Tema 09: Ejercicios Prácticos
# ## Manejo de Excepciones y Errores
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ---
# ## Bloque 1: Introducción a try-except

# %% [markdown]
# ### Ejercicio 1: División Segura 🟢
#
# Crea un programa que pida dos números al usuario y los divida. Maneja el error si el usuario ingresa 0 como divisor.
#
# **Salida esperada:**
# ```
# Introduce el dividendo: 10
# Introduce el divisor: 0
# Error: No se puede dividir por cero
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 2: Conversión a Entero 🟢
#
# Pide al usuario un número y conviértelo a entero. Maneja el error si el usuario ingresa texto en lugar de un número.
#
# **Ejemplo:**
# ```
# Introduce un número: abc
# Error: Debes introducir un número válido
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 3: Acceso a Índice de Lista 🟢
#
# Dada la lista `frutas = ['manzana', 'banana', 'naranja']`, pide al usuario un índice y muestra la fruta correspondiente. Maneja el error si el índice está fuera de rango.
#
# **Ejemplo:**
# ```
# Introduce un índice: 5
# Error: Índice fuera de rango
# ```

# %%
# Escribe tu código aquí
frutas = ['manzana', 'banana', 'naranja']

# %% [markdown]
# ---
# ## Bloque 2: Múltiples Excepciones

# %% [markdown]
# ### Ejercicio 4: Calculadora con Manejo de Errores 🟡
#
# Crea una calculadora que pida dos números y una operación (+, -, *, /). Maneja:
# - `ValueError`: si los números no son válidos
# - `ZeroDivisionError`: si se divide por cero
# - Cualquier otra excepción general
#
# **Ejemplo:**
# ```
# Primer número: 10
# Segundo número: abc
# Error: Los valores deben ser números
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 5: Acceso a Diccionario 🟡
#
# Dado el diccionario `edades = {'Ana': 25, 'Juan': 30, 'María': 28}`, pide un nombre al usuario y muestra su edad. Maneja:
# - `KeyError`: si el nombre no existe en el diccionario
# - Imprime un mensaje apropiado para cada caso

# %%
# Escribe tu código aquí
edades = {'Ana': 25, 'Juan': 30, 'María': 28}

# %% [markdown]
# ### Ejercicio 6: Lectura de Archivo 🟡
#
# Intenta abrir un archivo llamado `datos.txt` y leer su contenido. Maneja:
# - `FileNotFoundError`: si el archivo no existe
# - `PermissionError`: si no tienes permisos para leerlo
#
# **Pista:** Para probar, intenta abrir un archivo que no existe.

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 3: else y finally

# %% [markdown]
# ### Ejercicio 7: División con else 🟢
#
# Crea un programa que divida dos números. Usa:
# - `try`: para intentar la división
# - `except`: para manejar ZeroDivisionError
# - `else`: para imprimir el resultado si no hubo error
# - `finally`: para imprimir "Operación finalizada"

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 8: Archivo con finally 🟡
#
# Intenta abrir un archivo para lectura. Usa `finally` para asegurarte de que el archivo se cierre, exista o no un error.
#
# **Estructura:**
# ```python
# archivo = None
# try:
#     # abrir archivo
# except:
#     # manejar error
# finally:
#     # cerrar archivo si está abierto
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 4: Excepciones Personalizadas

# %% [markdown]
# ### Ejercicio 9: Excepción para Edad Negativa 🟡
#
# Crea una excepción personalizada `EdadNegativaError` que se lance cuando alguien intente crear una persona con edad negativa.
#
# **Ejemplo:**
# ```python
# class EdadNegativaError(Exception):
#     pass
#
# def crear_persona(nombre, edad):
#     if edad < 0:
#         raise EdadNegativaError("La edad no puede ser negativa")
#     return {'nombre': nombre, 'edad': edad}
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 10: Validador de Contraseñas 🔴
#
# Crea excepciones personalizadas para validar contraseñas:
# - `ContrasenaMuyCortaError`: si tiene menos de 8 caracteres
# - `ContrasenaSinMayusculaError`: si no tiene mayúsculas
# - `ContrasenaSinNumeroError`: si no tiene números
#
# Crea una función `validar_contrasena(password)` que lance la excepción apropiada.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 11: Excepción de Saldo Insuficiente 🟡
#
# Crea una clase `CuentaBancaria` con:
# - Una excepción `SaldoInsuficienteError`
# - Método `retirar(cantidad)` que lance la excepción si no hay suficiente saldo
#
# **Ejemplo:**
# ```python
# cuenta = CuentaBancaria(100)
# cuenta.retirar(150)  # Debe lanzar SaldoInsuficienteError
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 5: raise - Lanzar Excepciones

# %% [markdown]
# ### Ejercicio 12: Validar Rango de Edad 🟢
#
# Crea una función `validar_edad(edad)` que:
# - Lance `ValueError` si la edad es negativa
# - Lance `ValueError` si la edad es mayor que 120
# - Retorne `True` si la edad es válida

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 13: Validar Email 🟡
#
# Crea una función `validar_email(email)` que lance una excepción si:
# - El email no contiene @
# - El email no contiene un punto después del @
#
# **Ejemplo:**
# ```python
# validar_email('usuario@ejemplo.com')  # OK
# validar_email('usuarioejemplo.com')   # Error: falta @
# validar_email('usuario@ejemplo')      # Error: falta punto
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 6: assert - Aserciones

# %% [markdown]
# ### Ejercicio 14: Verificar Tipo de Dato 🟢
#
# Crea una función `calcular_area_rectangulo(base, altura)` que:
# - Use `assert` para verificar que base y altura sean números positivos
# - Calcule y retorne el área

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 15: Validar Lista No Vacía 🟢
#
# Crea una función `calcular_promedio(numeros)` que:
# - Use `assert` para verificar que la lista no esté vacía
# - Calcule y retorne el promedio

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 7: Logging

# %% [markdown]
# ### Ejercicio 16: Log Básico 🟡
#
# Crea un programa que:
# 1. Configure logging básico
# 2. Registre mensajes de diferentes niveles: DEBUG, INFO, WARNING, ERROR, CRITICAL
# 3. Intente dividir dos números y registre el resultado o el error

# %%
# Escribe tu código aquí
import logging

# %% [markdown]
# ### Ejercicio 17: Log en Archivo 🟡
#
# Crea un programa que:
# 1. Configure logging para guardar en un archivo `errores.log`
# 2. Registre todos los intentos de operaciones matemáticas
# 3. Registre específicamente los errores que ocurran

# %%
# Escribe tu código aquí
import logging

# %% [markdown]
# ---
# ## Bloque 8: Aplicaciones Prácticas

# %% [markdown]
# ### Ejercicio 18: Conversor de Unidades Seguro 🟡
#
# Crea un conversor de temperatura que:
# - Convierta entre Celsius, Fahrenheit y Kelvin
# - Valide que la temperatura en Kelvin no sea negativa
# - Maneje entradas no numéricas
# - Use logging para registrar conversiones y errores

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 19: Procesador de Lista de Números 🔴
#
# Crea una función `procesar_numeros(lista_str)` que:
# - Reciba una lista de strings que deberían ser números
# - Intente convertir cada elemento a float
# - Maneje elementos que no se puedan convertir (continúa con el siguiente)
# - Retorne:
#   - Lista de números válidos
#   - Lista de elementos que fallaron
#   - Estadísticas (suma, promedio, máximo, mínimo)
#
# **Ejemplo:**
# ```python
# datos = ['10', '20.5', 'abc', '30', '15.7', 'xyz']
# validos, invalidos, stats = procesar_numeros(datos)
# # validos = [10.0, 20.5, 30.0, 15.7]
# # invalidos = ['abc', 'xyz']
# # stats = {'suma': 76.2, 'promedio': 19.05, ...}
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 20: Sistema de Login 🔴
#
# Crea un sistema de login que:
# - Tenga un diccionario de usuarios: `{'usuario': 'contraseña'}`
# - Permita 3 intentos de login
# - Lance una excepción personalizada `CuentaBloqueadaError` después de 3 intentos fallidos
# - Lance `UsuarioNoExisteError` si el usuario no existe
# - Lance `ContrasenaIncorrectaError` si la contraseña es incorrecta
# - Use logging para registrar todos los intentos de login (exitosos y fallidos)
# - Retorne `True` si el login es exitoso

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 21: Gestor de Archivos CSV 🔴
#
# Crea un programa que:
# 1. Intente abrir un archivo CSV
# 2. Lea sus datos línea por línea
# 3. Maneje errores:
#    - Archivo no encontrado
#    - Errores de formato en líneas específicas
#    - Permisos insuficientes
# 4. Use `finally` para cerrar el archivo
# 5. Registre en log:
#    - Líneas procesadas correctamente
#    - Líneas con errores
#    - Total de líneas procesadas
#
# **Estructura del CSV de prueba:**
# ```
# nombre,edad,ciudad
# Ana,25,Madrid
# Juan,abc,Barcelona  # Error en edad
# María,30,Valencia
# ```

# %%
# Escribe tu código aquí

# Primero crea el archivo CSV de prueba:
csv_contenido = """nombre,edad,ciudad
Ana,25,Madrid
Juan,abc,Barcelona
María,30,Valencia
Pedro,28,Sevilla
"""

with open('datos_prueba.csv', 'w') as f:
    f.write(csv_contenido)

# Ahora escribe tu solución:

# %% [markdown]
# ### Ejercicio 22: Calculadora Avanzada con Historial 🔴
#
# Crea una calculadora que:
# - Soporte operaciones básicas: +, -, *, /, **, %
# - Maneje todos los errores posibles
# - Mantenga un historial de operaciones
# - Permita deshacer la última operación
# - Use logging para registrar:
#   - Cada operación realizada
#   - Errores encontrados
#   - Operaciones deshechas
# - Tenga un menú interactivo
#
# **Menú:**
# ```
# 1. Realizar operación
# 2. Ver historial
# 3. Deshacer última operación
# 4. Limpiar historial
# 5. Salir
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 9: Desafíos Finales

# %% [markdown]
# ### Ejercicio 23: Validador de Datos de Formulario 🔴
#
# Crea un validador completo para un formulario de registro que valide:
# - **Nombre**: no vacío, solo letras y espacios
# - **Edad**: número entre 18 y 100
# - **Email**: formato válido
# - **Teléfono**: exactamente 9 dígitos
# - **Contraseña**: mínimo 8 caracteres, una mayúscula, un número, un carácter especial
#
# Crea excepciones personalizadas para cada tipo de error y una función que valide todos los campos, registrando errores encontrados.
#
# **Ejemplo de uso:**
# ```python
# datos = {
#     'nombre': 'Juan Pérez',
#     'edad': 25,
#     'email': 'juan@ejemplo.com',
#     'telefono': '612345678',
#     'contrasena': 'Pass123!'
# }
#
# validar_formulario(datos)  # Retorna True o lanza excepciones
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 24: Sistema de Gestión de Inventario 🔴
#
# Crea un sistema completo de inventario con:
#
# **Excepciones personalizadas:**
# - `ProductoNoExisteError`
# - `StockInsuficienteError`
# - `PrecioInvalidoError`
# - `CantidadNegativaError`
#
# **Funcionalidades:**
# 1. Agregar productos (nombre, precio, stock)
# 2. Vender productos (reduce stock)
# 3. Reabastecer productos (aumenta stock)
# 4. Buscar productos
# 5. Generar reporte de inventario
# 6. Guardar/cargar inventario desde archivo JSON
#
# **Requisitos:**
# - Validar todos los datos
# - Manejar errores de archivo
# - Usar logging extensivo
# - Menú interactivo
# - Usar `finally` para guardar cambios

# %%
# Escribe tu código aquí
import json
import logging

# %% [markdown]
# ### Ejercicio 25: Analizador de Logs 🔴
#
# Crea un programa que:
# 1. Lea un archivo de log
# 2. Extraiga información:
#    - Número de errores por tipo
#    - Número de warnings
#    - Líneas con mensajes críticos
#    - Timestamp del primer y último error
# 3. Genere un reporte en formato:
#    - Consola
#    - Archivo de texto
#    - JSON
# 4. Maneje todos los errores posibles:
#    - Archivo no encontrado
#    - Formato de log incorrecto
#    - Líneas malformadas
#
# **Formato del log de entrada:**
# ```
# 2025-11-11 10:30:15 - ERROR - Error de conexión
# 2025-11-11 10:31:22 - WARNING - Memoria baja
# 2025-11-11 10:32:45 - CRITICAL - Sistema caído
# ```

# %%
# Escribe tu código aquí

# Primero crea un archivo de log de prueba:
log_contenido = """2025-11-11 10:30:15 - ERROR - Error de conexión a base de datos
2025-11-11 10:31:22 - WARNING - Memoria al 85%
2025-11-11 10:32:45 - CRITICAL - Sistema de respaldo inaccesible
2025-11-11 10:33:10 - INFO - Usuario login exitoso
2025-11-11 10:34:55 - ERROR - Timeout en API externa
2025-11-11 10:35:30 - WARNING - Disco casi lleno
2025-11-11 10:36:12 - ERROR - Error de conexión a base de datos
Línea malformada sin timestamp
2025-11-11 10:37:25 - DEBUG - Proceso completado
2025-11-11 10:38:40 - CRITICAL - Fallo total del sistema
"""

with open('sistema.log', 'w') as f:
    f.write(log_contenido)

# Ahora escribe tu solución:
