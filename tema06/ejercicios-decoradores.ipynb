# %% [markdown]
# # EJERCICIOS DE DECORADORES

# %% [markdown]
# ## Ejercicio 1: Decorador de depuración
#
# Crea un decorador llamado `debug` que imprima:
# - El nombre de la función
# - Los argumentos recibidos
# - El valor retornado
#
# **Ejemplo de uso:**
# ```python
# @debug
# def suma(a, b):
#     return a + b
#
# suma(3, 5)
# ```
#
# **Salida esperada:**
# ```
# Llamando a suma
#   Argumentos: (3, 5)
#   Resultado: 8
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 2: Decorador de validación de rango
#
# Crea un decorador `validar_rango(min_val, max_val)` que valide que todos los argumentos numéricos estén dentro del rango especificado. Si algún valor está fuera del rango, debe lanzar un `ValueError`.
#
# **Ejemplo de uso:**
# ```python
# @validar_rango(0, 100)
# def calcular_promedio(*notas):
#     return sum(notas) / len(notas)
#
# calcular_promedio(85, 90, 78)  # OK
# calcular_promedio(85, 150, 78)  # Error: 150 está fuera del rango
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 3: Decorador de caché con límite
#
# Crea un decorador `cache_limitado(max_size)` que:
# - Almacene en caché los resultados de una función
# - Mantenga como máximo `max_size` resultados en caché
# - Elimine el resultado más antiguo cuando se supere el límite (FIFO)
# - Imprima si el resultado viene del caché o se calcula nuevo
#
# **Pista:** Usa un diccionario y una lista para mantener el orden.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 4: Decorador de reintentos con backoff exponencial
#
# Crea un decorador `reintentar_exponencial(max_intentos=3, delay_base=1)` que:
# - Reintente una función si falla
# - Espere un tiempo creciente entre intentos: `delay_base`, `delay_base*2`, `delay_base*4`...
# - Después de `max_intentos`, lance la excepción original
#
# Usa `time.sleep()` para las esperas (usa valores pequeños para las pruebas).

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 5: Decorador de control de frecuencia (rate limiting)
#
# Crea un decorador `limitar_frecuencia(llamadas_max, periodo)` que:
# - Permita como máximo `llamadas_max` llamadas en `periodo` segundos
# - Si se supera el límite, lance una excepción `RateLimitError`
#
# **Ejemplo:** `@limitar_frecuencia(3, 5)` permite máximo 3 llamadas cada 5 segundos.
#
# **Pista:** Usa una lista para almacenar los timestamps de las llamadas.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 6: Decorador para hacer funciones "singleton"
#
# Crea un decorador `singleton` que haga que una función solo se ejecute una vez, sin importar cuántas veces se llame. Las llamadas posteriores deben retornar el mismo resultado de la primera ejecución.
#
# **Ejemplo:**
# ```python
# @singleton
# def inicializar_configuracion():
#     print("Cargando configuración...")
#     return {"api_key": "12345", "timeout": 30}
#
# config1 = inicializar_configuracion()  # Ejecuta la función
# config2 = inicializar_configuracion()  # Retorna el resultado anterior
# config1 is config2  # True (es el mismo objeto)
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 7: Decorador de estadísticas
#
# Crea un decorador `estadisticas` que lleve un registro de:
# - Número total de llamadas
# - Tiempo total de ejecución
# - Tiempo promedio por llamada
# - Tiempo mínimo y máximo
#
# Y que tenga un método `mostrar_estadisticas()` para imprimir estos datos.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 8: Sistema de permisos (Desafío)
#
# Crea un sistema de decoradores para control de acceso que incluya:
#
# 1. Decorador `requiere_login` que verifique si hay un usuario logueado
# 2. Decorador `requiere_permiso(permiso)` que verifique permisos específicos
# 3. Un contexto simulado de usuario actual con sus permisos
#
# **Estructura sugerida:**
# - Variable global `usuario_actual` con formato: `{'nombre': str, 'permisos': list}`
# - Decoradores que lancen `PermissionError` si no se cumplen las condiciones

# %%
# Escribe tu código aquí
