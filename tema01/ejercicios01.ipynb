# %% [markdown]
# # Tema 01: Ejercicios Prácticos
# ## Introducción y Primeros Pasos con Python
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ---
# ## Bloque 1: Variables y Tipos de Datos

# %% [markdown]
# ### Ejercicio 1: Tu Primer Programa 🟢
#
# Crea un programa que:
# 1. Guarde tu nombre en una variable llamada `mi_nombre`
# 2. Guarde tu edad en una variable llamada `mi_edad`
# 3. Muestre en pantalla: "Me llamo [nombre] y tengo [edad] años"
#
# **Ejemplo de salida:**
# ```
# Me llamo Ana y tengo 20 años
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 2: Tipos de Datos 🟢
#
# Crea las siguientes variables y muestra su tipo usando `type()`:
# - `producto`: el texto "Laptop"
# - `precio`: el número decimal 899.99
# - `cantidad`: el número entero 5
# - `disponible`: el valor booleano True

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 3: Información Personal 🟢
#
# Crea variables para almacenar:
# - Tu ciudad de residencia
# - Tu estatura en metros (ejemplo: 1.75)
# - Si tienes mascota (True/False)
# - Tu color favorito
#
# Luego muestra toda la información en pantalla de forma ordenada.

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 2: Operadores Aritméticos

# %% [markdown]
# ### Ejercicio 4: Calculadora Simple 🟢
#
# Crea dos variables `a = 15` y `b = 4`. Calcula y muestra:
# - La suma
# - La resta
# - La multiplicación
# - La división
# - La división entera
# - El resto de la división (módulo)
# - `a` elevado a `b`

# %%
# Escribe tu código aquí
a = 15
b = 4

# %% [markdown]
# ### Ejercicio 5: Área de un Círculo 🟢
#
# Calcula el área de un círculo con radio = 7.
#
# **Fórmula:** área = π × radio²
#
# **Pista:** Usa 3.14159 como valor de π

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 6: Conversión de Unidades 🟡
#
# Convierte 150 minutos a horas y minutos.
#
# **Ejemplo:** 150 minutos = 2 horas y 30 minutos
#
# **Pistas:**
# - Usa división entera (//) para obtener las horas
# - Usa módulo (%) para obtener los minutos restantes

# %%
# Escribe tu código aquí
minutos_totales = 150

# %% [markdown]
# ### Ejercicio 7: Precio con IVA 🟡
#
# Calcula el precio final de un producto que cuesta 50€ aplicándole un 21% de IVA.
#
# Muestra:
# - Precio base
# - IVA (21% del precio base)
# - Precio final (precio base + IVA)

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 3: Operadores de Comparación

# %% [markdown]
# ### Ejercicio 8: Comparaciones 🟢
#
# Dadas las variables `x = 25` e `y = 30`, evalúa y muestra el resultado de:
# - ¿x es igual a y?
# - ¿x es diferente de y?
# - ¿x es mayor que y?
# - ¿x es menor o igual que y?
# - ¿y es mayor o igual que 30?

# %%
# Escribe tu código aquí
x = 25
y = 30

# %% [markdown]
# ### Ejercicio 9: Verificación de Edad 🟢
#
# Crea una variable `edad = 17` y verifica:
# - Si es mayor o igual a 18 (mayor de edad)
# - Si es menor a 65 (no jubilado)
# - Si está entre 18 y 65 (edad laboral)
#
# Guarda cada verificación en una variable booleana y muéstrala.

# %%
# Escribe tu código aquí
edad = 17

# %% [markdown]
# ---
# ## Bloque 4: Operadores Lógicos

# %% [markdown]
# ### Ejercicio 10: Condiciones de Entrada 🟡
#
# En un parque de atracciones:
# - Altura mínima: 120 cm
# - Edad mínima: 8 años
#
# Verifica si una persona con `altura = 130` y `edad = 10` puede entrar.
#
# Debe cumplir AMBAS condiciones.

# %%
# Escribe tu código aquí
altura = 130
edad = 10

# %% [markdown]
# ### Ejercicio 11: Descuento Especial 🟡
#
# Una tienda ofrece descuento si:
# - Eres estudiante O
# - Tienes más de 65 años
#
# Verifica si una persona con `es_estudiante = True` y `edad = 22` tiene descuento.

# %%
# Escribe tu código aquí
es_estudiante = True
edad = 22

# %% [markdown]
# ### Ejercicio 12: Lógica Inversa 🟡
#
# Tienes las variables:
# ```python
# llueve = False
# hace_frio = True
# ```
#
# Determina:
# - ¿Hace buen tiempo? (no llueve Y no hace frío)
# - ¿Necesitas paraguas? (llueve)
# - ¿Puedes salir a pasear? (no llueve)

# %%
# Escribe tu código aquí
llueve = False
hace_frio = True

# %% [markdown]
# ---
# ## Bloque 5: Cadenas de Texto

# %% [markdown]
# ### Ejercicio 13: Concatenación Básica 🟢
#
# Crea variables para:
# - Nombre: "Juan"
# - Apellido: "Pérez"
# - Ciudad: "Madrid"
#
# Crea una frase: "Hola, soy Juan Pérez de Madrid"

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 14: Creando un Email 🟡
#
# Dadas las variables:
# ```python
# nombre = "maria"
# apellido = "garcia"
# dominio = "email.com"
# ```
#
# Crea un email con el formato: nombre.apellido@dominio
#
# **Resultado esperado:** maria.garcia@email.com

# %%
# Escribe tu código aquí
nombre = "maria"
apellido = "garcia"
dominio = "email.com"

# %% [markdown]
# ### Ejercicio 15: Repetición de Texto 🟢
#
# Crea un patrón decorativo usando el operador `*`.
#
# Crea una línea de 30 asteriscos (*) y úsala para crear un marco:
#
# ```
# ******************************
#     ¡Bienvenido a Python!
# ******************************
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 6: Entrada de Datos

# %% [markdown]
# ### Ejercicio 16: Saludo Personalizado 🟢
#
# Pide al usuario su nombre y muestra un saludo personalizado.
#
# **Ejemplo:**
# ```
# ¿Cuál es tu nombre? Ana
# ¡Hola, Ana! Bienvenido/a al curso de Python
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 17: Suma de Dos Números 🟢
#
# Pide al usuario dos números y muestra su suma.
#
# **Recuerda:** Debes convertir las entradas a números usando `int()` o `float()`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 18: Cálculo de Edad 🟡
#
# Pide al usuario:
# - Su año de nacimiento
#
# Calcula y muestra su edad aproximada (usa 2025 como año actual).
#
# **Ejemplo:**
# ```
# ¿En qué año naciste? 2000
# Tienes aproximadamente 25 años
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 7: Ejercicios Integradores

# %% [markdown]
# ### Ejercicio 19: Calculadora de IMC 🔴
#
# Crea un programa que:
# 1. Pida el peso en kg
# 2. Pida la altura en metros
# 3. Calcule el IMC (Índice de Masa Corporal)
#
# **Fórmula:** IMC = peso / (altura²)
#
# **Ejemplo:**
# ```
# Peso (kg): 70
# Altura (m): 1.75
# Tu IMC es: 22.86
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 20: Conversor de Temperatura 🔴
#
# Crea un programa que:
# 1. Pida una temperatura en grados Celsius
# 2. La convierta a Fahrenheit y Kelvin
# 3. Muestre los tres valores
#
# **Fórmulas:**
# - Fahrenheit = (Celsius × 9/5) + 32
# - Kelvin = Celsius + 273.15
#
# **Ejemplo:**
# ```
# Temperatura en °C: 25
# 25.0 °C = 77.0 °F = 298.15 K
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 21: Tienda Online Simple 🔴
#
# Crea un programa para una tienda que:
# 1. Pida el nombre del producto
# 2. Pida el precio unitario
# 3. Pida la cantidad
# 4. Calcule el subtotal
# 5. Aplique 21% de IVA
# 6. Muestre un ticket de compra
#
# **Ejemplo de salida:**
# ```
# ====== TICKET DE COMPRA ======
# Producto: Teclado
# Precio unitario: 25.00 €
# Cantidad: 2
# Subtotal: 50.00 €
# IVA (21%): 10.50 €
# TOTAL: 60.50 €
# ==============================
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 22: Intercambio de Variables 🔴
#
# Dadas dos variables:
# ```python
# a = 10
# b = 20
# ```
#
# Intercambia sus valores sin usar una tercera variable.
#
# **Pista:** En Python puedes hacer: `a, b = b, a`
#
# Muestra los valores antes y después del intercambio.

# %%
# Escribe tu código aquí
a = 10
b = 20

# %% [markdown]
# ---
# ## 🎯 Desafíos Extra (Opcional)

# %% [markdown]
# ### Desafío 1: Calculadora de Propina 🔴
#
# Crea un programa que:
# 1. Pida el total de la cuenta
# 2. Pida el porcentaje de propina (10, 15, 20, etc.)
# 3. Pida el número de personas
# 4. Calcule la propina total
# 5. Calcule cuánto paga cada persona (cuenta + propina dividido entre personas)
#
# Muestra todos los cálculos de forma clara.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Desafío 2: Calculadora de Distancia 🔴
#
# Crea un programa que calcule la distancia entre dos puntos en un plano cartesiano.
#
# Pide:
# - x1, y1 (coordenadas del primer punto)
# - x2, y2 (coordenadas del segundo punto)
#
# **Fórmula:** distancia = √[(x2-x1)² + (y2-y1)²]
#
# **Pista:** Para la raíz cuadrada usa: `numero ** 0.5`

# %%
# Escribe tu código aquí
