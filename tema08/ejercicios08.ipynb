# %% [markdown]
# # Tema 08: Ejercicios Prácticos
# ## Programación Orientada a Objetos
#
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ## Ejercicio 1: Sistema de Vehículos (Herencia)
#
# Crea un sistema de jerarquía de vehículos:
#
# 1. Clase base `Vehiculo` con:
#    - Atributos: marca, modelo, año, velocidad_actual
#    - Métodos: acelerar(), frenar(), obtener_info()
#
# 2. Clase `Coche(Vehiculo)` que añade:
#    - Atributo: numero_puertas
#    - Método: abrir_maletero()
#
# 3. Clase `Motocicleta(Vehiculo)` que añade:
#    - Atributo: tipo (deportiva, cruiser, touring)
#    - Método: hacer_caballito()
#
# 4. Clase `Camion(Vehiculo)` que añade:
#    - Atributos: capacidad_carga, carga_actual
#    - Métodos: cargar(), descargar()
#
# Implementa todos los métodos y crea instancias de cada tipo.

# %%
# Tu código aquí
class Vehiculo:
    pass

class Coche(Vehiculo):
    pass

class Motocicleta(Vehiculo):
    pass

class Camion(Vehiculo):
    pass

# Pruebas
# coche = Coche("Toyota", "Corolla", 2023, 4)
# moto = Motocicleta("Harley", "Road King", 2022, "cruiser")
# camion = Camion("Volvo", "FH16", 2021, 25000)

# %% [markdown]
# ## Ejercicio 2: Figuras Geométricas (Polimorfismo)
#
# Implementa un sistema de figuras geométricas:
#
# 1. Clase base `Figura` con métodos abstractos area() y perimetro()
# 2. Implementa las siguientes figuras:
#    - `Cuadrado`
#    - `Rectangulo`
#    - `Triangulo`
#    - `Circulo`
#    - `Pentagono` (regular)
#
# 3. Crea una función `comparar_areas(figura1, figura2)` que compare las áreas de dos figuras
# 4. Crea una función `figura_mayor_perimetro(lista_figuras)` que retorne la figura con mayor perímetro

# %%
import math

# Tu código aquí
class Figura:
    pass

class Cuadrado(Figura):
    pass

class Rectangulo(Figura):
    pass

class Triangulo(Figura):
    pass

class Circulo(Figura):
    pass

class Pentagono(Figura):
    pass

def comparar_areas(figura1, figura2):
    pass

def figura_mayor_perimetro(lista_figuras):
    pass

# Pruebas
# figuras = [
#     Cuadrado(5),
#     Rectangulo(4, 6),
#     Circulo(3),
#     Triangulo(3, 4, 5)
# ]

# %% [markdown]
# ## Ejercicio 3: Sistema Bancario (Herencia y Polimorfismo)
#
# Crea un sistema bancario con diferentes tipos de cuentas:
#
# 1. Clase base `CuentaBancaria`:
#    - Atributos: titular, numero_cuenta, saldo
#    - Métodos: depositar(), retirar(), obtener_saldo()
#
# 2. `CuentaAhorro(CuentaBancaria)`:
#    - Atributo adicional: tasa_interes
#    - Método: calcular_interes_mensual()
#    - Sobrescribe retirar() para permitir máximo 3 retiros por mes
#
# 3. `CuentaCorriente(CuentaBancaria)`:
#    - Atributo adicional: sobregiro_permitido
#    - Sobrescribe retirar() para permitir sobregiro
#
# 4. `CuentaNomina(CuentaBancaria)`:
#    - Método: recibir_nomina(monto)
#    - No cobra comisiones por retiros
#
# 5. Crea una clase `Banco` que administre múltiples cuentas

# %%
# Tu código aquí
class CuentaBancaria:
    pass

class CuentaAhorro(CuentaBancaria):
    pass

class CuentaCorriente(CuentaBancaria):
    pass

class CuentaNomina(CuentaBancaria):
    pass

class Banco:
    pass

# Pruebas
# banco = Banco("Banco Nacional")
# cuenta1 = CuentaAhorro("Juan Pérez", "001", 1000, 0.05)
# cuenta2 = CuentaCorriente("María García", "002", 500, 200)
# banco.agregar_cuenta(cuenta1)
# banco.agregar_cuenta(cuenta2)

# %% [markdown]
# ## Ejercicio 4: Universidad (Composición)
#
# Diseña un sistema universitario usando composición:
#
# 1. Clase `Materia`:
#    - Atributos: nombre, codigo, creditos
#
# 2. Clase `Estudiante`:
#    - Atributos: nombre, id, materias_inscritas (lista)
#    - Métodos: inscribir_materia(), dar_baja_materia(), obtener_creditos_totales()
#
# 3. Clase `Profesor`:
#    - Atributos: nombre, id, materias_impartidas (lista)
#    - Métodos: asignar_materia(), obtener_carga_academica()
#
# 4. Clase `Departamento`:
#    - Atributos: nombre, profesores (lista), materias_ofrecidas (lista)
#    - Métodos: agregar_profesor(), agregar_materia(), listar_profesores()
#
# 5. Clase `Universidad`:
#    - Atributos: nombre, departamentos (lista), estudiantes (lista)
#    - Métodos: agregar_departamento(), matricular_estudiante(), generar_reporte()

# %%
# Tu código aquí
class Materia:
    pass

class Estudiante:
    pass

class Profesor:
    pass

class Departamento:
    pass

class Universidad:
    pass

# Pruebas
# uni = Universidad("Universidad Nacional")
# dept_cs = Departamento("Ciencias de la Computación")
# materia = Materia("Programación Avanzada", "CS301", 4)

# %% [markdown]
# ## Ejercicio 5: E-commerce (Composición Compleja)
#
# Crea un sistema de comercio electrónico:
#
# 1. Clase `Producto`:
#    - Atributos: nombre, precio, stock, categoria
#    - Métodos: aplicar_descuento(), verificar_disponibilidad()
#
# 2. Clase `ItemCarrito`:
#    - Atributos: producto, cantidad
#    - Método: calcular_subtotal()
#
# 3. Clase `CarritoCompras`:
#    - Atributos: items (lista de ItemCarrito)
#    - Métodos: agregar_producto(), remover_producto(), calcular_total(), vaciar_carrito()
#
# 4. Clase `Cliente`:
#    - Atributos: nombre, email, direccion, carrito
#    - Métodos: realizar_compra(), ver_historial()
#
# 5. Clase `Pedido`:
#    - Atributos: numero_pedido, cliente, items, fecha, estado, total
#    - Métodos: cambiar_estado(), generar_factura()
#
# 6. Clase `Tienda`:
#    - Atributos: nombre, productos, clientes, pedidos
#    - Métodos: agregar_producto(), procesar_pedido(), buscar_producto()

# %%
from datetime import datetime

# Tu código aquí
class Producto:
    pass

class ItemCarrito:
    pass

class CarritoCompras:
    pass

class Cliente:
    pass

class Pedido:
    pass

class Tienda:
    pass

# Pruebas
# tienda = Tienda("TechStore")
# producto1 = Producto("Laptop", 1200, 10, "Electrónica")
# cliente = Cliente("Ana López", "ana@email.com", "Calle 123")

# %% [markdown]
# ## Ejercicio 6: Juego RPG (Herencia Múltiple)
#
# Crea un sistema de personajes para un juego de rol:
#
# 1. Clases base de habilidades:
#    - `Guerrero`: tiene atributos de fuerza y resistencia
#    - `Mago`: tiene atributos de inteligencia y mana
#    - `Arquero`: tiene atributos de destreza y puntería
#
# 2. Crea clases híbridas usando herencia múltiple:
#    - `Paladin(Guerrero, Mago)`: guerrero con magia divina
#    - `Ranger(Arquero, Mago)`: arquero con magia de naturaleza
#    - `MagoGuerrero(Mago, Guerrero)`: combina magia y combate cuerpo a cuerpo
#
# 3. Cada personaje debe tener:
#    - Atributos: nombre, nivel, vida, experiencia
#    - Métodos: atacar(), defender(), subir_nivel(), usar_habilidad_especial()
#
# 4. Implementa un sistema de combate básico

# %%
import random

# Tu código aquí
class Personaje:
    pass

class Guerrero:
    pass

class Mago:
    pass

class Arquero:
    pass

class Paladin(Guerrero, Mago):
    pass

class Ranger(Arquero, Mago):
    pass

class MagoGuerrero(Mago, Guerrero):
    pass

def combate(personaje1, personaje2):
    pass

# Pruebas
# paladin = Paladin("Arthas", 10)
# ranger = Ranger("Legolas", 10)

# %% [markdown]
# ## Ejercicio 7: Sobrecarga de Operadores
#
# Crea una clase `Matriz` que represente una matriz matemática:
#
# 1. Implementa los siguientes operadores:
#    - `+`: suma de matrices
#    - `-`: resta de matrices
#    - `*`: multiplicación de matrices
#    - `==`: comparación de matrices
#    - `[]`: acceso a elementos (usar `__getitem__` y `__setitem__`)
#
# 2. Métodos adicionales:
#    - `transponer()`: retorna la matriz transpuesta
#    - `determinante()`: calcula el determinante (para matrices 2x2 y 3x3)
#    - `es_cuadrada()`: verifica si es cuadrada
#    - `dimensiones()`: retorna tupla (filas, columnas)
#
# 3. Métodos especiales:
#    - `__str__`: representación legible
#    - `__repr__`: representación técnica

# %%
# Tu código aquí
class Matriz:
    def __init__(self, datos):
        """
        datos: lista de listas representando la matriz
        Ejemplo: [[1, 2], [3, 4]]
        """
        pass
    
    def __add__(self, otra):
        pass
    
    def __sub__(self, otra):
        pass
    
    def __mul__(self, otra):
        pass
    
    def __eq__(self, otra):
        pass
    
    def __getitem__(self, key):
        pass
    
    def __setitem__(self, key, value):
        pass
    
    def __str__(self):
        pass
    
    def __repr__(self):
        pass
    
    def transponer(self):
        pass
    
    def determinante(self):
        pass

# Pruebas
# m1 = Matriz([[1, 2], [3, 4]])
# m2 = Matriz([[5, 6], [7, 8]])
# print(m1 + m2)
# print(m1 * m2)

# %% [markdown]
# ## Ejercicio 8: Sistema de Notificaciones (Duck Typing)
#
# Crea un sistema flexible de notificaciones usando duck typing:
#
# 1. Implementa diferentes canales de notificación:
#    - `NotificacionEmail`: envía por correo
#    - `NotificacionSMS`: envía por mensaje de texto
#    - `NotificacionPush`: envía notificación push
#    - `NotificacionSlack`: envía a Slack
#
# 2. Todos deben tener el método `enviar(destinatario, mensaje)`
#
# 3. Clase `GestorNotificaciones`:
#    - Debe poder trabajar con cualquier tipo de notificación
#    - Método `enviar_multiple()`: envía por múltiples canales
#    - Método `enviar_con_prioridad()`: envía según prioridad del mensaje
#
# 4. Implementa un sistema de registro (log) de notificaciones enviadas

# %%
from datetime import datetime

# Tu código aquí
class NotificacionEmail:
    pass

class NotificacionSMS:
    pass

class NotificacionPush:
    pass

class NotificacionSlack:
    pass

class GestorNotificaciones:
    pass

# Pruebas
# gestor = GestorNotificaciones()
# gestor.agregar_canal(NotificacionEmail())
# gestor.agregar_canal(NotificacionSMS())
# gestor.enviar_multiple("usuario@email.com", "Mensaje importante")

# %% [markdown]
# ## Ejercicio 9: Restaurante (Composición y Herencia)
#
# Diseña un sistema para un restaurante:
#
# 1. Clase `Ingrediente`:
#    - Atributos: nombre, costo, unidad, cantidad_disponible
#
# 2. Clase `Plato`:
#    - Atributos: nombre, ingredientes (diccionario), precio, categoria
#    - Métodos: calcular_costo(), verificar_disponibilidad()
#
# 3. Jerarquía de platos:
#    - `Entrada(Plato)`
#    - `PlatoPrincipal(Plato)`
#    - `Postre(Plato)`
#    - `Bebida(Plato)`
#
# 4. Clase `Pedido`:
#    - Atributos: numero_mesa, platos, estado
#    - Métodos: agregar_plato(), calcular_total(), aplicar_descuento()
#
# 5. Clase `Menu`:
#    - Agrupa todos los platos por categoría
#    - Método para buscar platos
#
# 6. Clase `Restaurante`:
#    - Gestiona inventario, pedidos y menú

# %%
# Tu código aquí
class Ingrediente:
    pass

class Plato:
    pass

class Entrada(Plato):
    pass

class PlatoPrincipal(Plato):
    pass

class Postre(Plato):
    pass

class Bebida(Plato):
    pass

class Pedido:
    pass

class Menu:
    pass

class Restaurante:
    pass

# Pruebas
# restaurante = Restaurante("La Buena Mesa")
# entrada = Entrada("Ensalada César", {...}, 8.50, "Entradas")

# %% [markdown]
# ## Ejercicio 10: Biblioteca Digital (Clases Abstractas)
#
# Crea un sistema de biblioteca digital usando clases abstractas:
#
# 1. Clase abstracta `Publicacion`:
#    - Métodos abstractos: prestar(), devolver(), obtener_info()
#    - Atributos comunes: titulo, autor, año_publicacion, disponible
#
# 2. Implementa las siguientes publicaciones:
#    - `Libro`: páginas, ISBN, genero
#    - `Revista`: numero_edicion, mes
#    - `AudioLibro`: duracion_minutos, narrador
#    - `Periodico`: fecha_publicacion
#
# 3. Clase `Usuario`:
#    - Atributos: nombre, id, publicaciones_prestadas
#    - Métodos: tomar_prestado(), devolver_publicacion()
#
# 4. Clase `Biblioteca`:
#    - Gestiona catálogo y usuarios
#    - Métodos: buscar_por_titulo(), buscar_por_autor(), generar_reporte()
#
# 5. Implementa sistema de multas por retraso

# %%
from abc import ABC, abstractmethod
from datetime import datetime, timedelta

# Tu código aquí
class Publicacion(ABC):
    pass

class Libro(Publicacion):
    pass

class Revista(Publicacion):
    pass

class AudioLibro(Publicacion):
    pass

class Periodico(Publicacion):
    pass

class Usuario:
    pass

class Biblioteca:
    pass

# Pruebas
# biblioteca = Biblioteca("Biblioteca Central")
# libro = Libro("Python Avanzado", "John Doe", 2023, 400, "978-0-123456-78-9", "Programación")
# usuario = Usuario("Ana García", "U001")

# %% [markdown]
# ## Ejercicio Desafío: Sistema de Transporte Multimodal
#
# Crea un sistema completo que combine todos los conceptos:
#
# 1. **Jerarquía de Transportes** (Herencia):
#    - Base: `MedioTransporte`
#    - Terrestres: `Autobus`, `Tren`, `Metro`
#    - Aéreos: `Avion`, `Helicoptero`
#    - Acuáticos: `Barco`, `Ferry`
#
# 2. **Sistema de Rutas** (Composición):
#    - `Estacion`: punto de origen/destino
#    - `Ruta`: conecta estaciones, tiene distancia y duración
#    - `Horario`: gestiona frecuencias de viajes
#
# 3. **Sistema de Pasajeros** (Polimorfismo):
#    - `Pasajero`: puede comprar diferentes tipos de boletos
#    - `BoletoRegular`, `BoletoEstudiante`, `BoletoTercedaEdad`
#    - Cada tipo tiene diferentes descuentos
#
# 4. **Gestor de Viajes**:
#    - Buscar rutas entre dos estaciones
#    - Calcular tiempo y costo total
#    - Sugerir ruta óptima (más rápida o más barata)
#    - Gestionar reservas
#
# 5. **Características adicionales**:
#    - Sistema de puntos de lealtad
#    - Alertas de retrasos
#    - Estadísticas de uso
#
# **Requisitos**:
# - Debe usar herencia, composición y polimorfismo
# - Implementar al menos 3 operadores sobrecargados
# - Usar clases abstractas donde sea apropiado
# - Código bien documentado

# %%
from abc import ABC, abstractmethod
from datetime import datetime, timedelta
from typing import List, Optional

# Tu código aquí - ¡Este es el desafío completo!
# Implementa todo el sistema siguiendo las especificaciones

class MedioTransporte(ABC):
    pass

# ... continúa con el resto de las clases
