# %% [markdown]
# # Tema 05: Ejercicios Prácticos
# ## Diccionarios y Conjuntos
#
# **Instrucciones generales:**
# - Lee cuidadosamente cada ejercicio
# - Escribe tu código en la celda correspondiente
# - Ejecuta el código para comprobar que funciona
# - Prueba con diferentes valores de entrada
#
# **Nivel de dificultad:**
# - 🟢 Básico
# - 🟡 Intermedio
# - 🔴 Avanzado

# %% [markdown]
# ---
# ## Bloque 1: Crear y Acceder a Diccionarios

# %% [markdown]
# ### Ejercicio 1: Crear un Diccionario de Persona 🟢
#
# Crea un diccionario llamado `persona` con la siguiente información:
# - Nombre: Tu nombre
# - Edad: Tu edad
# - Ciudad: Tu ciudad
# - Profesión: Tu profesión o "Estudiante"
#
# Imprime el diccionario completo.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 2: Acceder a Valores 🟢
#
# Dado el siguiente diccionario, imprime:
# 1. El nombre del producto
# 2. El precio
# 3. El stock
#
# ```python
# producto = {
#     "nombre": "Laptop",
#     "precio": 899.99,
#     "stock": 15,
#     "categoria": "Electrónica"
# }
# ```

# %%
# Escribe tu código aquí
producto = {
    "nombre": "Laptop",
    "precio": 899.99,
    "stock": 15,
    "categoria": "Electrónica"
}

# %% [markdown]
# ### Ejercicio 3: Método get() 🟢
#
# Dado el diccionario del ejercicio anterior, usa el método `get()` para:
# 1. Obtener la categoría
# 2. Intentar obtener "descuento" (que no existe) con valor por defecto 0
# 3. Intentar obtener "marca" con valor por defecto "Sin marca"

# %%
# Escribe tu código aquí
producto = {
    "nombre": "Laptop",
    "precio": 899.99,
    "stock": 15,
    "categoria": "Electrónica"
}

# %% [markdown]
# ### Ejercicio 4: Crear Diccionario desde Listas 🟡
#
# Dadas dos listas, crea un diccionario combinándolas:
#
# ```python
# claves = ["nombre", "edad", "ciudad"]
# valores = ["Ana", 25, "Madrid"]
# ```
#
# **Pista:** Usa `zip()` y `dict()`

# %%
# Escribe tu código aquí
claves = ["nombre", "edad", "ciudad"]
valores = ["Ana", 25, "Madrid"]

# %% [markdown]
# ---
# ## Bloque 2: Modificar Diccionarios

# %% [markdown]
# ### Ejercicio 5: Agregar y Modificar 🟢
#
# Dado el diccionario:
# ```python
# libro = {
#     "titulo": "Python para todos",
#     "autor": "Juan Pérez"
# }
# ```
#
# 1. Agrega la clave "año" con valor 2023
# 2. Agrega la clave "paginas" con valor 350
# 3. Modifica el autor a "Juan Pérez García"
# 4. Imprime el diccionario final

# %%
# Escribe tu código aquí
libro = {
    "titulo": "Python para todos",
    "autor": "Juan Pérez"
}

# %% [markdown]
# ### Ejercicio 6: Eliminar Elementos 🟢
#
# Dado el diccionario:
# ```python
# usuario = {
#     "nombre": "Carlos",
#     "email": "carlos@example.com",
#     "password": "123456",
#     "edad": 30
# }
# ```
#
# 1. Elimina la clave "password" usando `pop()` y guárdala en una variable
# 2. Elimina la clave "edad" usando `del`
# 3. Imprime el diccionario resultante

# %%
# Escribe tu código aquí
usuario = {
    "nombre": "Carlos",
    "email": "carlos@example.com",
    "password": "123456",
    "edad": 30
}

# %% [markdown]
# ### Ejercicio 7: Método update() 🟡
#
# Dado el diccionario:
# ```python
# config = {
#     "idioma": "es",
#     "tema": "claro"
# }
# ```
#
# Usa `update()` para agregar/modificar:
# - "tema": "oscuro"
# - "notificaciones": True
# - "volumen": 75
#
# Imprime el diccionario resultante.

# %%
# Escribe tu código aquí
config = {
    "idioma": "es",
    "tema": "claro"
}

# %% [markdown]
# ### Ejercicio 8: Copiar Diccionarios 🟡
#
# Crea un diccionario `original = {"a": 1, "b": 2, "c": 3}`
#
# 1. Crea una copia usando el método `copy()`
# 2. Modifica la copia agregando `"d": 4`
# 3. Imprime ambos diccionarios para verificar que son independientes

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 3: Métodos de Diccionarios

# %% [markdown]
# ### Ejercicio 9: keys(), values(), items() 🟢
#
# Dado el diccionario:
# ```python
# notas = {
#     "matemáticas": 8.5,
#     "física": 7.0,
#     "química": 9.0,
#     "historia": 8.0
# }
# ```
#
# 1. Imprime todas las asignaturas (claves)
# 2. Imprime todas las notas (valores)
# 3. Imprime todos los pares asignatura-nota

# %%
# Escribe tu código aquí
notas = {
    "matemáticas": 8.5,
    "física": 7.0,
    "química": 9.0,
    "historia": 8.0
}

# %% [markdown]
# ### Ejercicio 10: Recorrer Diccionario 🟢
#
# Usando el diccionario del ejercicio anterior, recorre el diccionario e imprime cada asignatura con su nota en el formato:
# ```
# Matemáticas: 8.5
# Física: 7.0
# ...
# ```

# %%
# Escribe tu código aquí
notas = {
    "matemáticas": 8.5,
    "física": 7.0,
    "química": 9.0,
    "historia": 8.0
}

# %% [markdown]
# ### Ejercicio 11: Verificar Existencia 🟢
#
# Dado el diccionario:
# ```python
# inventario = {
#     "manzanas": 50,
#     "bananas": 30,
#     "naranjas": 45
# }
# ```
#
# 1. Verifica si "manzanas" está en el inventario
# 2. Verifica si "peras" está en el inventario
# 3. Imprime mensajes apropiados para cada caso

# %%
# Escribe tu código aquí
inventario = {
    "manzanas": 50,
    "bananas": 30,
    "naranjas": 45
}

# %% [markdown]
# ### Ejercicio 12: setdefault() 🟡
#
# Dado el diccionario:
# ```python
# config = {"idioma": "es", "tema": "claro"}
# ```
#
# Usa `setdefault()` para:
# 1. Obtener el idioma (ya existe)
# 2. Obtener/crear "volumen" con valor por defecto 50
# 3. Obtener/crear "notificaciones" con valor por defecto True
# 4. Imprime el diccionario final

# %%
# Escribe tu código aquí
config = {"idioma": "es", "tema": "claro"}

# %% [markdown]
# ---
# ## Bloque 4: Dictionary Comprehension

# %% [markdown]
# ### Ejercicio 13: Cuadrados 🟡
#
# Crea un diccionario usando comprehension donde:
# - Las claves sean los números del 1 al 5
# - Los valores sean sus cuadrados
#
# **Resultado esperado:** `{1: 1, 2: 4, 3: 9, 4: 16, 5: 25}`

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 14: Longitud de Palabras 🟡
#
# Dada la lista:
# ```python
# frutas = ["manzana", "banana", "naranja", "pera", "uva"]
# ```
#
# Crea un diccionario usando comprehension donde las claves sean las frutas y los valores sean sus longitudes.

# %%
# Escribe tu código aquí
frutas = ["manzana", "banana", "naranja", "pera", "uva"]

# %% [markdown]
# ### Ejercicio 15: Filtrar Diccionario 🔴
#
# Dado el diccionario:
# ```python
# precios = {
#     "manzanas": 2.50,
#     "bananas": 1.20,
#     "naranjas": 3.00,
#     "peras": 2.80,
#     "uvas": 4.50
# }
# ```
#
# Crea un nuevo diccionario usando comprehension que solo contenga productos con precio mayor a 2.50.

# %%
# Escribe tu código aquí
precios = {
    "manzanas": 2.50,
    "bananas": 1.20,
    "naranjas": 3.00,
    "peras": 2.80,
    "uvas": 4.50
}

# %% [markdown]
# ### Ejercicio 16: Invertir Diccionario 🟡
#
# Dado el diccionario:
# ```python
# original = {"a": 1, "b": 2, "c": 3}
# ```
#
# Crea un nuevo diccionario donde las claves y valores estén intercambiados.
#
# **Resultado esperado:** `{1: "a", 2: "b", 3: "c"}`

# %%
# Escribe tu código aquí
original = {"a": 1, "b": 2, "c": 3}

# %% [markdown]
# ---
# ## Bloque 5: Diccionarios Anidados

# %% [markdown]
# ### Ejercicio 17: Crear Diccionario Anidado 🟡
#
# Crea un diccionario de estudiantes donde cada estudiante tenga:
# - ID como clave (ej: "est001", "est002")
# - Diccionario con: nombre, edad, y lista de notas
#
# Crea al menos 3 estudiantes.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 18: Acceder a Datos Anidados 🟡
#
# Usando el diccionario del ejercicio anterior:
# 1. Imprime el nombre del primer estudiante
# 2. Imprime las notas del segundo estudiante
# 3. Calcula e imprime el promedio del tercer estudiante

# %%
# Escribe tu código aquí
# (Usa el diccionario del ejercicio anterior)

# %% [markdown]
# ### Ejercicio 19: Recorrer Diccionario Anidado 🔴
#
# Usando el diccionario de estudiantes, recórrelo e imprime la información de cada estudiante en el formato:
# ```
# ID: est001
#   Nombre: Ana
#   Edad: 20
#   Promedio: 8.33
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
# ## Bloque 6: Conjuntos (Sets) - Básico

# %% [markdown]
# ### Ejercicio 20: Crear Conjuntos 🟢
#
# 1. Crea un conjunto con los números del 1 al 5
# 2. Crea un conjunto con las vocales
# 3. Crea un conjunto desde la lista `[1, 2, 3, 2, 4, 3, 5]` y observa cómo se eliminan duplicados

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 21: Agregar y Eliminar 🟢
#
# Dado el conjunto `colores = {"rojo", "verde", "azul"}`:
# 1. Agrega "amarillo"
# 2. Agrega "negro"
# 3. Elimina "verde" usando `remove()`
# 4. Intenta eliminar "blanco" usando `discard()` (no dará error)
# 5. Imprime el conjunto final

# %%
# Escribe tu código aquí
colores = {"rojo", "verde", "azul"}

# %% [markdown]
# ### Ejercicio 22: Eliminar Duplicados 🟢
#
# Dada la lista:
# ```python
# numeros = [1, 2, 3, 2, 4, 1, 5, 3, 6, 4, 7, 5]
# ```
#
# 1. Convierte la lista a conjunto para eliminar duplicados
# 2. Convierte de nuevo a lista ordenada
# 3. Imprime el resultado

# %%
# Escribe tu código aquí
numeros = [1, 2, 3, 2, 4, 1, 5, 3, 6, 4, 7, 5]

# %% [markdown]
# ---
# ## Bloque 7: Operaciones con Conjuntos

# %% [markdown]
# ### Ejercicio 23: Unión 🟡
#
# Dados los conjuntos:
# ```python
# curso_a = {"Ana", "Juan", "María", "Carlos"}
# curso_b = {"Juan", "Pedro", "María", "Laura"}
# ```
#
# 1. Encuentra todos los estudiantes únicos (unión)
# 2. Usa tanto el operador `|` como el método `union()`
# 3. Imprime el resultado

# %%
# Escribe tu código aquí
curso_a = {"Ana", "Juan", "María", "Carlos"}
curso_b = {"Juan", "Pedro", "María", "Laura"}

# %% [markdown]
# ### Ejercicio 24: Intersección 🟡
#
# Usando los mismos conjuntos del ejercicio anterior:
# 1. Encuentra los estudiantes que están en ambos cursos (intersección)
# 2. Usa tanto el operador `&` como el método `intersection()`
# 3. Imprime el resultado

# %%
# Escribe tu código aquí
curso_a = {"Ana", "Juan", "María", "Carlos"}
curso_b = {"Juan", "Pedro", "María", "Laura"}

# %% [markdown]
# ### Ejercicio 25: Diferencia 🟡
#
# Usando los mismos conjuntos:
# 1. Encuentra estudiantes solo en curso_a (diferencia)
# 2. Encuentra estudiantes solo en curso_b
# 3. Imprime ambos resultados

# %%
# Escribe tu código aquí
curso_a = {"Ana", "Juan", "María", "Carlos"}
curso_b = {"Juan", "Pedro", "María", "Laura"}

# %% [markdown]
# ### Ejercicio 26: Diferencia Simétrica 🟡
#
# Usando los mismos conjuntos:
# 1. Encuentra estudiantes que están en un curso pero no en ambos (diferencia simétrica)
# 2. Usa tanto el operador `^` como el método `symmetric_difference()`
# 3. Imprime el resultado

# %%
# Escribe tu código aquí
curso_a = {"Ana", "Juan", "María", "Carlos"}
curso_b = {"Juan", "Pedro", "María", "Laura"}

# %% [markdown]
# ### Ejercicio 27: Subconjuntos 🟡
#
# Dados los conjuntos:
# ```python
# a = {1, 2, 3}
# b = {1, 2, 3, 4, 5}
# ```
#
# 1. Verifica si `a` es subconjunto de `b`
# 2. Verifica si `b` es superconjunto de `a`
# 3. Imprime los resultados

# %%
# Escribe tu código aquí
a = {1, 2, 3}
b = {1, 2, 3, 4, 5}

# %% [markdown]
# ---
# ## Bloque 8: Ejercicios de Aplicación Práctica

# %% [markdown]
# ### Ejercicio 28: Contar Frecuencia de Palabras 🔴
#
# Dado el texto:
# ```python
# texto = "python es genial python es poderoso python es versátil python es fácil"
# ```
#
# Crea un diccionario que cuente cuántas veces aparece cada palabra.
#
# **Resultado esperado:**
# ```
# {"python": 4, "es": 4, "genial": 1, "poderoso": 1, "versátil": 1, "fácil": 1}
# ```

# %%
# Escribe tu código aquí
texto = "python es genial python es poderoso python es versátil python es fácil"

# %% [markdown]
# ### Ejercicio 29: Agenda Telefónica 🔴
#
# Crea un programa de agenda que:
# 1. Tenga un diccionario vacío para contactos
# 2. Permita agregar contactos (nombre: teléfono)
# 3. Permita buscar un contacto por nombre
# 4. Permita eliminar un contacto
# 5. Permita mostrar todos los contactos
# 6. Tenga un menú que se repita hasta que el usuario elija salir
#
# **Funcionalidades:**
# - Agregar contacto
# - Buscar contacto
# - Eliminar contacto
# - Mostrar todos
# - Salir

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 30: Análisis de Estudiantes 🔴
#
# Dado el siguiente diccionario de estudiantes:
# ```python
# estudiantes = {
#     "est001": {"nombre": "Ana", "notas": [8, 9, 7, 8]},
#     "est002": {"nombre": "Juan", "notas": [6, 7, 5, 6]},
#     "est003": {"nombre": "María", "notas": [9, 10, 9, 10]},
#     "est004": {"nombre": "Carlos", "notas": [5, 6, 4, 5]}
# }
# ```
#
# Calcula y muestra:
# 1. El promedio de cada estudiante
# 2. El estudiante con mejor promedio
# 3. El estudiante con peor promedio
# 4. Cuántos estudiantes aprobaron (promedio >= 5)
# 5. El promedio general de todos los estudiantes

# %%
# Escribe tu código aquí
estudiantes = {
    "est001": {"nombre": "Ana", "notas": [8, 9, 7, 8]},
    "est002": {"nombre": "Juan", "notas": [6, 7, 5, 6]},
    "est003": {"nombre": "María", "notas": [9, 10, 9, 10]},
    "est004": {"nombre": "Carlos", "notas": [5, 6, 4, 5]}
}

# %% [markdown]
# ### Ejercicio 31: Inventario de Tienda 🔴
#
# Crea un sistema de inventario que use un diccionario con la estructura:
# ```python
# {
#     "producto": {"precio": float, "stock": int, "categoria": str}
# }
# ```
#
# El programa debe permitir:
# 1. Agregar productos
# 2. Actualizar stock
# 3. Actualizar precio
# 4. Buscar productos por categoría
# 5. Calcular valor total del inventario
# 6. Mostrar productos con stock bajo (< 10 unidades)

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 32: Análisis de Redes Sociales 🔴
#
# Dados dos conjuntos de seguidores de diferentes redes sociales:
# ```python
# instagram = {"Ana", "Juan", "María", "Carlos", "Lucía", "Pedro"}
# twitter = {"Juan", "Pedro", "María", "Laura", "Diego", "Carmen"}
# ```
#
# Calcula y muestra:
# 1. Seguidores en ambas redes
# 2. Seguidores solo en Instagram
# 3. Seguidores solo en Twitter
# 4. Total de seguidores únicos
# 5. Porcentaje de seguidores que están en ambas redes

# %%
# Escribe tu código aquí
instagram = {"Ana", "Juan", "María", "Carlos", "Lucía", "Pedro"}
twitter = {"Juan", "Pedro", "María", "Laura", "Diego", "Carmen"}

# %% [markdown]
# ### Ejercicio 33: Traductor Simple 🔴
#
# Crea un programa traductor que:
# 1. Tenga un diccionario de traducciones español-inglés
# 2. Permita agregar nuevas traducciones
# 3. Permita traducir palabras
# 4. Permita traducir frases completas (palabra por palabra)
# 5. Muestre "[DESCONOCIDO]" para palabras sin traducción
#
# **Diccionario inicial:**
# ```python
# traducciones = {
#     "hola": "hello",
#     "mundo": "world",
#     "python": "python",
#     "es": "is",
#     "genial": "great"
# }
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 34: Sistema de Votación 🔴
#
# Crea un sistema de votación que:
# 1. Tenga un diccionario de candidatos con sus votos (inicialmente 0)
# 2. Permita registrar votos
# 3. Muestre resultados actuales
# 4. Determine al ganador
# 5. Muestre porcentaje de votos de cada candidato
# 6. Detecte si hay empate
#
# **Candidatos iniciales:**
# ```python
# candidatos = {
#     "Candidato A": 0,
#     "Candidato B": 0,
#     "Candidato C": 0
# }
# ```

# %%
# Escribe tu código aquí

# %% [markdown]
# ### Ejercicio 35: Análisis de Texto Avanzado 🔴
#
# Dado un texto, crea un programa que:
# 1. Cuente la frecuencia de cada palabra
# 2. Encuentre las 5 palabras más frecuentes
# 3. Cuente cuántas palabras únicas hay
# 4. Encuentre palabras que aparecen solo una vez
# 5. Calcule la longitud promedio de las palabras
#
# **Texto de ejemplo:**
# ```python
# texto = """Python es un lenguaje de programación interpretado cuya filosofía
# hace hincapié en la legibilidad de su código. Se trata de un lenguaje de
# programación multiparadigma, ya que soporta programación orientada a objetos,
# programación imperativa y programación funcional."""
# ```
#
# **Pista:** Usa métodos de strings para limpiar el texto (minúsculas, quitar puntuación)

# %%
# Escribe tu código aquí
